# %%
# %pip install pandas scikit-learn pyarrow lightgbm
# Out:
# Requirement already satisfied: pandas in /venv/main/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in /venv/main/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: pyarrow in /venv/main/lib/python3.10/site-packages (20.0.0)
# Requirement already satisfied: lightgbm in /venv/main/lib/python3.10/site-packages (4.6.0)
# Requirement already satisfied: pytz>=2020.1 in /venv/main/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /venv/main/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /venv/main/lib/python3.10/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: tzdata>=2022.7 in /venv/main/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: six>=1.5 in /venv/main/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
import lightgbm as lgb

# %%
df = pd.read_feather('Wide_S_P_100_format.feather')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

print(df.shape)
print(df.columns[:5])
df.head()
# Out:
# (15928, 101)
# Index(['AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE'], dtype='object', name='Ticker')
# Ticker      AAPL  ABBV  ABT  ACN  ADBE  AIG  AMD  AMGN  AMT  AMZN  ...  TXN  \
# Date                                                               ...
# 1962-01-02   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  ...  NaN
# 1962-01-03   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  ...  NaN
# 1962-01-04   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  ...  NaN
# 1962-01-05   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  ...  NaN
# 1962-01-08   NaN   NaN  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  ...  NaN
#
# Ticker      UNH  UNP  UPS  USB   V  VZ  WFC  WMT       XOM
# Date
# 1962-01-02  NaN  NaN  NaN  NaN NaN NaN  NaN  NaN       NaN
# 1962-01-03  NaN  NaN  NaN  NaN NaN NaN  NaN  NaN  0.014852
# 1962-01-04  NaN  NaN  NaN  NaN NaN NaN  NaN  NaN  0.002439
# 1962-01-05  NaN  NaN  NaN  NaN NaN NaN  NaN  NaN -0.021899
# 1962-01-08  NaN  NaN  NaN  NaN NaN NaN  NaN  NaN -0.002488
#
# [5 rows x 101 columns]

# %%
df.tail()
# Out:
# Ticker          AAPL      ABBV       ABT       ACN      ADBE       AIG  \
# Date
# 2025-04-08 -0.049818 -0.058322 -0.007288 -0.011696 -0.002055  0.001418
# 2025-04-09  0.153289  0.023738  0.024929  0.065923  0.072471  0.066306
# 2025-04-10 -0.042394 -0.031361 -0.019994 -0.049076 -0.040012 -0.017749
# 2025-04-11  0.040594  0.004879  0.019116 -0.003085  0.006913  0.007621
# 2025-04-14  0.022054  0.023136  0.008512  0.019167 -0.004426 -0.005734
#
# Ticker           AMD      AMGN       AMT      AMZN  ...       TXN       UNH  \
# Date                                                ...
# 2025-04-08 -0.064921 -0.032552 -0.040911 -0.026247  ... -0.051883  0.054088
# 2025-04-09  0.238205  0.038643  0.013779  0.119770  ...  0.160879  0.045961
# 2025-04-10 -0.084056 -0.033254  0.004049 -0.051701  ... -0.076106  0.027485
# 2025-04-11  0.052988  0.016240  0.031943  0.020141  ... -0.057471  0.008530
# 2025-04-14  0.011777  0.027764  0.021433 -0.014875  ...  0.022900 -0.020702
#
# Ticker           UNP       UPS       USB         V        VZ       WFC  \
# Date
# 2025-04-08 -0.008096 -0.038091 -0.010870 -0.012968 -0.009629 -0.001448
# 2025-04-09  0.073270  0.084204  0.079670  0.078373  0.017074  0.068460
# 2025-04-10 -0.018834 -0.031106 -0.052163 -0.023524  0.016772 -0.048545
# 2025-04-11 -0.003329  0.005385  0.016376  0.027079  0.018872 -0.009507
# 2025-04-14  0.016835  0.016378  0.008980  0.005339  0.013035  0.009438
#
# Ticker           WMT       XOM
# Date
# 2025-04-08 -0.024335 -0.021080
# 2025-04-09  0.095488  0.049916
# 2025-04-10  0.011272 -0.055482
# 2025-04-11  0.024170  0.032122
# 2025-04-14  0.020797  0.002424
#
# [5 rows x 101 columns]

# %%
n_lags = 60
# Step 1: split original series first
df_train = df[(df.index.year >= 2000) & (df.index.year <= 2012)]
df_calib = df[(df.index.year >= 2013) & (df.index.year <= 2019)]
df_test = df[(df.index.year >= 2020) & (df.index.year <= 2025)]

# Step 2: for each set, generate lagged data individually
def make_lagged_data(df_part, n_lags):
    full_rows = []
    for ticker in df_part.columns:
        series = df_part[ticker]
        lagged = pd.concat({f'lag_{i}': series.shift(i) for i in range(1, n_lags+1)}, axis=1)
        lagged['target'] = series
        lagged['ticker'] = ticker
        lagged['Date'] = series.index
        full_rows.append(lagged)
    return pd.concat(full_rows).dropna().reset_index(drop=True)

train_data = make_lagged_data(df_train, n_lags)
calib_data = make_lagged_data(df_calib, n_lags)
test_data = make_lagged_data(df_test, n_lags)

feature_cols = [f'lag_{i}' for i in range(1, n_lags+1)]

X_train = train_data[feature_cols]
y_train = train_data['target']

X_calib = calib_data[feature_cols]
y_calib = calib_data['target']

X_test = test_data[feature_cols]
y_test = test_data['target']

print (X_train.shape, X_calib.shape, X_test.shape)
print(X_train.head())
print(X_train.tail())
print(X_calib.head())
print(X_calib.tail())
print(X_test.head())
print(X_test.tail())
# Out:
# (285365, 60) (169568, 60) (127879, 60)
#       lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7  \
# 0 -0.003135  0.006310 -0.018577 -0.019938  0.068550  0.097053 -0.016000
# 1 -0.022912 -0.003135  0.006310 -0.018577 -0.019938  0.068550  0.097053
# 2 -0.074943 -0.022912 -0.003135  0.006310 -0.018577 -0.019938  0.068550
# 3  0.080020 -0.074943 -0.022912 -0.003135  0.006310 -0.018577 -0.019938
# 4 -0.018408  0.080020 -0.074943 -0.022912 -0.003135  0.006310 -0.018577
#
#       lag_8     lag_9    lag_10  ...    lag_51    lag_52    lag_53    lag_54  \
# 0  0.028278  0.045699  0.017505  ...  0.038114  0.109677 -0.059973 -0.051151
# 1 -0.016000  0.028278  0.045699  ...  0.034848  0.038114  0.109677 -0.059973
# 2  0.097053 -0.016000  0.028278  ...  0.025256  0.034848  0.038114  0.109677
# 3  0.068550  0.097053 -0.016000  ...  0.065103  0.025256  0.034848  0.038114
# 4 -0.019938  0.068550  0.097053  ... -0.019273  0.065103  0.025256  0.034848
#
#      lag_55    lag_56    lag_57    lag_58    lag_59    lag_60
# 0 -0.017588  0.047369 -0.086538  0.014633 -0.084310  0.088754
# 1 -0.051151 -0.017588  0.047369 -0.086538  0.014633 -0.084310
# 2 -0.059973 -0.051151 -0.017588  0.047369 -0.086538  0.014633
# 3  0.109677 -0.059973 -0.051151 -0.017588  0.047369 -0.086538
# 4  0.038114  0.109677 -0.059973 -0.051151 -0.017588  0.047369
#
# [5 rows x 60 columns]
#            lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7  \
# 285360 -0.018674  0.005088 -0.012505  0.007764  0.008969 -0.005644 -0.009726
# 285361 -0.003554 -0.018674  0.005088 -0.012505  0.007764  0.008969 -0.005644
# 285362  0.001726 -0.003554 -0.018674  0.005088 -0.012505  0.007764  0.008969
# 285363 -0.002412  0.001726 -0.003554 -0.018674  0.005088 -0.012505  0.007764
# 285364 -0.020263 -0.002412  0.001726 -0.003554 -0.018674  0.005088 -0.012505
#
#            lag_8     lag_9    lag_10  ...    lag_51    lag_52    lag_53  \
# 285360  0.005169  0.006560 -0.002144  ... -0.005934  0.001404  0.003578
# 285361 -0.009726  0.005169  0.006560  ... -0.011940 -0.005934  0.001404
# 285362 -0.005644 -0.009726  0.005169  ...  0.001538 -0.011940 -0.005934
# 285363  0.008969 -0.005644 -0.009726  ... -0.001536  0.001538 -0.011940
# 285364  0.007764  0.008969 -0.005644  ...  0.005273 -0.001536  0.001538
#
#           lag_54    lag_55    lag_56    lag_57    lag_58    lag_59    lag_60
# 285360  0.005671 -0.000218 -0.000872  0.003827 -0.003813  0.006248 -0.005559
# 285361  0.003578  0.005671 -0.000218 -0.000872  0.003827 -0.003813  0.006248
# 285362  0.001404  0.003578  0.005671 -0.000218 -0.000872  0.003827 -0.003813
# 285363 -0.005934  0.001404  0.003578  0.005671 -0.000218 -0.000872  0.003827
# 285364 -0.011940 -0.005934  0.001404  0.003578  0.005671 -0.000218 -0.000872
#
# [5 rows x 60 columns]
#       lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7  \
# 0 -0.020837 -0.019647 -0.005263  0.003615  0.020277  0.001438 -0.005303
# 1 -0.031062 -0.020837 -0.019647 -0.005263  0.003615  0.020277  0.001438
# 2  0.002052 -0.031062 -0.020837 -0.019647 -0.005263  0.003615  0.020277
# 3  0.005119  0.002052 -0.031062 -0.020837 -0.019647 -0.005263  0.003615
# 4 -0.009885  0.005119  0.002052 -0.031062 -0.020837 -0.019647 -0.005263
#
#       lag_8     lag_9    lag_10  ...    lag_51    lag_52    lag_53    lag_54  \
# 0 -0.002699  0.027183  0.025803  ... -0.031550 -0.035653 -0.006132  0.012397
# 1 -0.005303 -0.002699  0.027183  ...  0.041509 -0.031550 -0.035653 -0.006132
# 2  0.001438 -0.005303 -0.002699  ... -0.006738  0.041509 -0.031550 -0.035653
# 3  0.020277  0.001438 -0.005303  ... -0.005331 -0.006738  0.041509 -0.031550
# 4  0.003615  0.020277  0.001438  ...  0.009540 -0.005331 -0.006738  0.041509
#
#      lag_55    lag_56    lag_57    lag_58    lag_59    lag_60
# 0 -0.015629  0.002691 -0.005882 -0.027855 -0.012622  0.031682
# 1  0.012397 -0.015629  0.002691 -0.005882 -0.027855 -0.012622
# 2 -0.006132  0.012397 -0.015629  0.002691 -0.005882 -0.027855
# 3 -0.035653 -0.006132  0.012397 -0.015629  0.002691 -0.005882
# 4 -0.031550 -0.035653 -0.006132  0.012397 -0.015629  0.002691
#
# [5 rows x 60 columns]
#            lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7  \
# 169563  0.005004  0.007926 -0.006870  0.002727 -0.004572  0.011123 -0.015780
# 169564 -0.003841  0.005004  0.007926 -0.006870  0.002727 -0.004572  0.011123
# 169565  0.001571 -0.003841  0.005004  0.007926 -0.006870  0.002727 -0.004572
# 169566 -0.003422  0.001571 -0.003841  0.005004  0.007926 -0.006870  0.002727
# 169567 -0.005866 -0.003422  0.001571 -0.003841  0.005004  0.007926 -0.006870
#
#            lag_8     lag_9    lag_10  ...    lag_51    lag_52    lag_53  \
# 169563  0.020011 -0.001448 -0.008614  ...  0.010696  0.012011  0.011095
# 169564 -0.015780  0.020011 -0.001448  ...  0.002899  0.010696  0.012011
# 169565  0.011123 -0.015780  0.020011  ...  0.003469  0.002899  0.010696
# 169566 -0.004572  0.011123 -0.015780  ... -0.017142  0.003469  0.002899
# 169567  0.002727 -0.004572  0.011123  ... -0.001319 -0.017142  0.003469
#
#           lag_54    lag_55    lag_56    lag_57    lag_58    lag_59    lag_60
# 169563 -0.019406 -0.013774  0.014563  0.012360 -0.026106 -0.023510 -0.012171
# 169564  0.011095 -0.019406 -0.013774  0.014563  0.012360 -0.026106 -0.023510
# 169565  0.012011  0.011095 -0.019406 -0.013774  0.014563  0.012360 -0.026106
# 169566  0.010696  0.012011  0.011095 -0.019406 -0.013774  0.014563  0.012360
# 169567  0.002899  0.010696  0.012011  0.011095 -0.019406 -0.013774  0.014563
#
# [5 rows x 60 columns]
#       lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7  \
# 0 -0.041402  0.052623 -0.005509  0.100325 -0.021244 -0.063485 -0.007662
# 1  0.028538 -0.041402  0.052623 -0.005509  0.100325 -0.021244 -0.063485
# 2 -0.002041  0.028538 -0.041402  0.052623 -0.005509  0.100325 -0.021244
# 3 -0.052617 -0.002041  0.028538 -0.041402  0.052623 -0.005509  0.100325
# 4  0.016687 -0.052617 -0.002041  0.028538 -0.041402  0.052623 -0.005509
#
#       lag_8     lag_9    lag_10  ...    lag_51    lag_52    lag_53    lag_54  \
# 0 -0.024480  0.043970 -0.128647  ... -0.004285 -0.013503  0.021364  0.002261
# 1 -0.007662 -0.024480  0.043970  ...  0.012526 -0.004285 -0.013503  0.021364
# 2 -0.063485 -0.007662 -0.024480  ...  0.011071  0.012526 -0.004285 -0.013503
# 3 -0.021244 -0.063485 -0.007662  ... -0.006777  0.011071  0.012526 -0.004285
# 4  0.100325 -0.021244 -0.063485  ...  0.003570 -0.006777  0.011071  0.012526
#
#      lag_55    lag_56    lag_57    lag_58    lag_59    lag_60
# 0  0.021240  0.016086 -0.004703  0.007968 -0.009722  0.022816
# 1  0.002261  0.021240  0.016086 -0.004703  0.007968 -0.009722
# 2  0.021364  0.002261  0.021240  0.016086 -0.004703  0.007968
# 3 -0.013503  0.021364  0.002261  0.021240  0.016086 -0.004703
# 4 -0.004285 -0.013503  0.021364  0.002261  0.021240  0.016086
#
# [5 rows x 60 columns]
#            lag_1     lag_2     lag_3     lag_4     lag_5     lag_6     lag_7  \
# 127874 -0.013418 -0.071956 -0.052583 -0.003108  0.000925  0.010193 -0.001357
# 127875 -0.021080 -0.013418 -0.071956 -0.052583 -0.003108  0.000925  0.010193
# 127876  0.049916 -0.021080 -0.013418 -0.071956 -0.052583 -0.003108  0.000925
# 127877 -0.055482  0.049916 -0.021080 -0.013418 -0.071956 -0.052583 -0.003108
# 127878  0.032122 -0.055482  0.049916 -0.021080 -0.013418 -0.071956 -0.052583
#
#            lag_8     lag_9    lag_10  ...    lag_51    lag_52    lag_53  \
# 127874 -0.003213  0.014409  0.006822  ... -0.013527  0.005661 -0.017404
# 127875 -0.001357 -0.003213  0.014409  ...  0.013897 -0.013527  0.005661
# 127876  0.010193 -0.001357 -0.003213  ... -0.019334  0.013897 -0.013527
# 127877  0.000925  0.010193 -0.001357  ...  0.005831 -0.019334  0.013897
# 127878 -0.003108  0.000925  0.010193  ...  0.008282  0.005831 -0.019334
#
#           lag_54    lag_55    lag_56    lag_57    lag_58    lag_59    lag_60
# 127874 -0.007568  0.008983 -0.001704  0.016314  0.003935  0.025812 -0.003647
# 127875 -0.017404 -0.007568  0.008983 -0.001704  0.016314  0.003935  0.025812
# 127876  0.005661 -0.017404 -0.007568  0.008983 -0.001704  0.016314  0.003935
# 127877 -0.013527  0.005661 -0.017404 -0.007568  0.008983 -0.001704  0.016314
# 127878  0.013897 -0.013527  0.005661 -0.017404 -0.007568  0.008983 -0.001704
#
# [5 rows x 60 columns]

# %%
param_grid = {
    "n_estimators":       [300, 400, 500],     # headroom for early-stop
    "learning_rate":      [0.01, 0.02, 0.03],
    "num_leaves":         [31, 63, 127, 255],  # primary depth control
    "max_depth":          [-1],                # unlimited (let num_leaves rule)
    "min_child_samples":  [20, 50, 100],
    "feature_fraction":   [0.7, 0.85, 1.0],    # ≈ colsample_bytree
    "bagging_fraction":   [0.7, 0.85, 1.0],    # ≈ subsample
    "bagging_freq":       [1],                 # activates bagging_fraction
    "reg_alpha":          [0.0, 0.1],
    "reg_lambda":         [1, 5, 10],
}

base_lgb = lgb.LGBMRegressor(
    objective="regression",
    device_type="gpu",
    gpu_use_dp=False,
    random_state=42,
    verbose=-1,
    n_jobs=1,
)

random_search = RandomizedSearchCV(
    estimator=base_lgb,
    param_distributions=param_grid,
    n_iter=200,
    scoring="neg_mean_squared_error",
    cv=5,
    verbose=3,
    random_state=42,
    n_jobs=1,                 
)

random_search.fit(X_train, y_train)

best_params = random_search.best_params_
print("Best hyperparameters found:")
print(random_search.best_params_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=   9.2s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=   8.5s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=   8.5s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=   8.6s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=   8.5s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  11.4s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  10.8s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  10.8s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  10.9s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  10.7s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  30.2s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  29.6s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  29.8s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  30.0s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  29.2s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  12.8s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  12.2s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  12.4s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  12.5s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  12.3s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  21.4s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  20.5s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  21.1s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  21.2s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  20.8s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.4s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=   8.9s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.1s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.2s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=   9.1s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  27.8s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  27.3s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  27.7s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  27.6s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  27.8s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  41.0s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  40.4s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  40.5s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  40.4s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  40.1s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  32.8s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  31.5s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  31.9s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  32.3s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  31.7s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  11.9s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  11.3s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  11.4s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  11.5s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  11.2s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   9.5s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   9.0s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   9.1s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   9.2s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   9.0s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  22.9s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  22.1s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  22.2s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  22.4s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  22.1s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   9.4s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=   8.9s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   9.0s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   9.0s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=   8.9s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  38.8s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  38.3s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  38.8s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  38.8s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  38.5s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  14.3s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  13.8s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  14.0s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  14.0s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  13.9s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  38.1s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  37.9s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  38.6s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  38.3s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  38.2s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  10.3s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  10.0s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  10.1s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  10.1s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  10.0s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  41.7s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  40.9s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  41.0s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  41.2s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  40.9s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  10.3s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=   9.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  10.0s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   9.9s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=   9.8s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  12.1s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  11.6s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  11.8s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  11.9s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  11.8s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  22.3s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  21.7s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  21.9s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  21.9s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  21.6s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  17.7s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  17.1s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  17.5s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  17.4s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  17.3s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=   8.2s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=   7.9s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=   8.0s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=   8.0s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=   7.9s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  13.6s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  13.1s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  13.3s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  13.4s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  13.0s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  21.9s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  21.2s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  21.0s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  21.3s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  20.8s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   8.4s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   7.9s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   7.9s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   8.0s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   7.8s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=   8.3s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=   7.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=   7.9s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=   7.9s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=   7.8s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  21.5s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  21.2s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  21.7s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  21.5s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  21.5s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   7.2s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   6.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   6.9s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   6.9s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=31, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   6.8s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  34.0s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  33.0s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  33.5s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  33.5s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  33.0s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  46.2s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  45.2s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  45.8s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  46.1s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  45.6s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  44.5s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  44.5s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  45.1s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  44.8s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  44.5s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  26.0s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  25.4s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  25.7s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  25.6s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  25.4s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  33.4s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  32.9s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  33.4s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  33.2s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  33.0s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.3s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=   8.8s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   8.9s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.0s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=   8.8s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   9.6s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   9.1s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   9.3s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=   9.3s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=   9.1s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  14.4s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  13.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  14.1s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  14.0s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  13.8s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  28.2s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  27.6s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  28.3s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  28.1s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  27.9s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  35.9s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  35.8s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  36.4s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  36.2s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.85, learning_rate=0.03, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  36.1s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  12.7s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  12.1s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  12.4s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  12.4s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  12.3s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  20.4s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  19.9s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  20.3s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  20.3s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  20.1s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  14.6s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  14.0s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  14.4s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  14.2s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=63, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  14.1s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  29.4s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  28.3s
# ...
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  22.5s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  22.6s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  22.8s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.02, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=127, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  22.5s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  42.4s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  41.2s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  41.7s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=  41.9s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=255, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=  41.4s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   6.9s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=   6.6s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   6.6s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.001 total time=   6.7s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.1, reg_lambda=1;, score=-0.000 total time=   6.6s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  10.1s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=   9.6s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.8s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=   9.7s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=0.7, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=   9.6s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  27.9s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  26.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  26.8s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  27.4s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=20, n_estimators=500, num_leaves=127, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  26.7s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  16.6s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  15.8s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  16.2s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  16.3s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  15.8s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  20.9s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  20.0s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  20.2s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  20.2s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  20.0s
# [CV 1/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  15.4s
# [CV 2/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  15.0s
# [CV 3/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  15.3s
# [CV 4/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  15.2s
# [CV 5/5] END bagging_fraction=0.85, bagging_freq=1, feature_fraction=0.7, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=300, num_leaves=127, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  15.1s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  39.1s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  38.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  38.8s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.001 total time=  39.1s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=100, n_estimators=400, num_leaves=255, reg_alpha=0.1, reg_lambda=5;, score=-0.000 total time=  38.5s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  17.4s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  16.7s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  17.1s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.001 total time=  17.0s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=100, n_estimators=500, num_leaves=63, reg_alpha=0.1, reg_lambda=10;, score=-0.000 total time=  16.8s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=   6.0s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=   5.8s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=   5.8s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=   5.8s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.85, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=300, num_leaves=31, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=   5.7s
# [CV 1/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  13.6s
# [CV 2/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  12.8s
# [CV 3/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  13.0s
# [CV 4/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.001 total time=  13.1s
# [CV 5/5] END bagging_fraction=0.7, bagging_freq=1, feature_fraction=1.0, learning_rate=0.02, max_depth=-1, min_child_samples=20, n_estimators=400, num_leaves=63, reg_alpha=0.0, reg_lambda=10;, score=-0.000 total time=  12.8s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  31.7s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  30.9s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  31.0s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.001 total time=  31.0s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=1.0, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=400, num_leaves=255, reg_alpha=0.0, reg_lambda=5;, score=-0.000 total time=  30.9s
# [CV 1/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  20.6s
# [CV 2/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  20.1s
# [CV 3/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  20.5s
# [CV 4/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.001 total time=  20.6s
# [CV 5/5] END bagging_fraction=1.0, bagging_freq=1, feature_fraction=0.7, learning_rate=0.03, max_depth=-1, min_child_samples=50, n_estimators=300, num_leaves=255, reg_alpha=0.0, reg_lambda=1;, score=-0.000 total time=  20.3s
# Best hyperparameters found:
# {'reg_lambda': 1, 'reg_alpha': 0.1, 'num_leaves': 255, 'n_estimators': 500, 'min_child_samples': 20, 'max_depth': -1, 'learning_rate': 0.03, 'feature_fraction': 0.7, 'bagging_freq': 1, 'bagging_fraction': 0.85}

# %%
# Normal point prediction model (MSE)
gbr = lgb.LGBMRegressor(
    objective='regression',
    random_state=42,
    **best_params
)
gbr.fit(X_train, y_train)

# Lower quantile model (5%)
gbr_lower = lgb.LGBMRegressor(
    objective='quantile',
    alpha=0.05,
    random_state=42,
    **best_params
)
gbr_lower.fit(X_train, y_train)

# Upper quantile model (95%)
gbr_upper = lgb.LGBMRegressor(
    objective='quantile',
    alpha=0.95,
    random_state=42,
    **best_params
)
gbr_upper.fit(X_train, y_train)
# Out:
# LGBMRegressor(alpha=0.95, bagging_fraction=0.85, bagging_freq=1,
#               feature_fraction=0.7, learning_rate=0.03, n_estimators=500,
#               num_leaves=255, objective='quantile', random_state=42,
#               reg_alpha=0.1, reg_lambda=1)

# %%
pred_calib = gbr.predict(X_calib)
pred_test = gbr.predict(X_test)

pred_lower_calib = gbr_lower.predict(X_calib)
pred_upper_calib = gbr_upper.predict(X_calib)

pred_lower_test = gbr_lower.predict(X_test)
pred_upper_test = gbr_upper.predict(X_test)

# %%
# Extract aligned metadata
dates_calib = calib_data["Date"].reset_index(drop=True)
dates_test = test_data["Date"].reset_index(drop=True)
tickers_calib = calib_data["ticker"].reset_index(drop=True)
tickers_test = test_data["ticker"].reset_index(drop=True)

# Save point predictions (calibration)
df_pred_calib = pd.DataFrame({
    'Date': dates_calib,
    'Ticker': tickers_calib,
    'pred_calib': pred_calib,
    'y_calib': y_calib.reset_index(drop=True)
})
df_pred_calib.to_csv('pred_calib.csv', index=False)

# Save point predictions (test)
df_pred_test = pd.DataFrame({
    'Date': dates_test,
    'Ticker': tickers_test,
    'pred_test': pred_test,
    'y_test': y_test.reset_index(drop=True)
})
df_pred_test.to_csv('pred_test.csv', index=False)

# Save quantile predictions (calibration)
df_quantile_calib = pd.DataFrame({
    'Date': dates_calib,
    'Ticker': tickers_calib,
    'pred_lower_calib': pred_lower_calib,
    'pred_upper_calib': pred_upper_calib,
    'y_calib': y_calib.reset_index(drop=True)
})
df_quantile_calib.to_csv('quantile_calib.csv', index=False)

# Save quantile predictions (test)
df_quantile_test = pd.DataFrame({
    'Date': dates_test,
    'Ticker': tickers_test,
    'pred_lower_test': pred_lower_test,
    'pred_upper_test': pred_upper_test,
    'y_test': y_test.reset_index(drop=True)
})
df_quantile_test.to_csv('quantile_test.csv', index=False)
